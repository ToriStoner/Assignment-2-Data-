# %% [markdown]
# <a href="https://colab.research.google.com/github/ToriStoner/Assignment-2-Data-/blob/main/DS4002_Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# going to import the basic packages that are necesssary for reading and visualizing the data
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from textblob import TextBlob
import nltk
import plotly.express as px
from textblob import Word
nltk.download('wordnet') # WordNet itself is primarily for English,
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
# going to read in the dataset
df = pd.read_csv("RestaurantData.csv", parse_dates = ['CommentDate', 'Date'], date_parser=pd.to_datetime,infer_datetime_format=True)
df.head(11)
# okay yay the data has been read in perfectly
# Out:
# <ipython-input-10-b4a08cb1ec89>:2: FutureWarning:
#
# The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#
# <ipython-input-10-b4a08cb1ec89>:2: FutureWarning:
#
# The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#     Rank CommentDate       Date RestaurantName  \
# 0      1  2023-09-16 2023-09-17      GRANVILLE
# 1      1  2023-09-15 2023-09-17      GRANVILLE
# 2      1  2023-09-07 2023-09-17      GRANVILLE
# 3      1  2023-09-06 2023-09-17      GRANVILLE
# 4      1  2023-09-05 2023-09-17      GRANVILLE
# 5      1  2023-09-04 2023-09-17      GRANVILLE
# 6      1  2023-09-03 2023-09-17      GRANVILLE
# 7      1  2023-09-03 2023-09-17      GRANVILLE
# 8      1  2023-08-31 2023-09-17      GRANVILLE
# 9      1  2023-08-31 2023-09-17      GRANVILLE
# 10     2  2023-09-16 2023-09-17  Running Goose
#
#                                               Comment  \
# 0   Great ambiance indoors and attentive staff. Re...
# 1   Wrong wrong wrong.   AIf you don't fit the Ty ...
# 2   Bad service!! The worst servers. Marcos the ma...
# 3   One of my absolute favorite places in WeHo for...
# 4   Always a good experience and food is great.Tea...
# 5   These five stars are for the food, service, an...
# 6   Visited Granville for a quick lunch and had an...
# 7   Great ambience, generous portions, delicious c...
# 8   Food was fine. Follow up service was non exist...
# 9   The food was fine and the ambiance was nice. O...
# 10  Visited this restaurant based off of a recomme...
#
#                                        Address  StarRating  NumberOfReviews  \
# 0   8701 Beverly Blvd West Hollywood, CA 90048         4.4             2672
# 1   8701 Beverly Blvd West Hollywood, CA 90048         4.4             2672
# 2   8701 Beverly Blvd West Hollywood, CA 90048         4.4             2672
# 3   8701 Beverly Blvd West Hollywood, CA 90048         4.4             2672
# 4   8701 Beverly Blvd West Hollywood, CA 90048         4.4             2672
# 5   8701 Beverly Blvd West Hollywood, CA 90048         4.4             2672
# 6   8701 Beverly Blvd West Hollywood, CA 90048         4.4             2672
# 7   8701 Beverly Blvd West Hollywood, CA 90048         4.4             2672
# 8   8701 Beverly Blvd West Hollywood, CA 90048         4.4             2672
# 9   8701 Beverly Blvd West Hollywood, CA 90048         4.4             2672
# 10  1620 N Cahuenga Blvd Los Angeles, CA 90028         4.3             1701
#
#                             Style Price
# 0   American (New), Cocktail Bars    $$
# 1   American (New), Cocktail Bars    $$
# 2   American (New), Cocktail Bars    $$
# 3   American (New), Cocktail Bars    $$
# 4   American (New), Cocktail Bars    $$
# 5   American (New), Cocktail Bars    $$
# 6   American (New), Cocktail Bars    $$
# 7   American (New), Cocktail Bars    $$
# 8   American (New), Cocktail Bars    $$
# 9   American (New), Cocktail Bars    $$
# 10     Gastropubs, Latin American    $$

# %%
# important to note that there are actually only 235 restaurants yay fun!
df_plot = df.copy()

# Split the strings in 'colB' into lists
df_plot['Style'] = df_plot['Style'].str.split(',')

# Explode 'colB' so each element gets its own row, duplicating 'colA' values
df_exploded = df_plot.explode('Style', ignore_index=True)
df_exploded.head()
#------------------------------------------------------------------------
df_exploded['Style'].str.strip().value_counts()
# Sort the DataFrame by 'Count' in descending order and take the top 20
df_style_most = df_exploded['Style'].str.strip().value_counts().reset_index()
df_style_most.columns = ['Style', 'Count']
df_style_most = df_style_most.sort_values(by='Count', ascending=False).head(20)

# Create the Plotly figure
fig = px.bar(df_style_most, x='Style', y='Count',
             title='Top 20 Styles',
             labels={'Style': 'Style', 'Count': 'Count'},
             color='Style')

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4edf72a4-592e-4b4f-8f0f-f5979098cc77" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4edf72a4-592e-4b4f-8f0f-f5979098cc77")) {                    Plotly.newPlot(                        "4edf72a4-592e-4b4f-8f0f-f5979098cc77",                        [{"alignmentgroup":"True","hovertemplate":"Style=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"American (New)","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"American (New)","offsetgroup":"American (New)","orientation":"v","showlegend":true,"textposition":"auto","x":["American (New)"],"xaxis":"x","y":[464],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Style=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Korean","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Korean","offsetgroup":"Korean","orientation":"v","showlegend":true,"textposition":"auto","x":["Korean"],"xaxis":"x","y":[420],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Style=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cocktail Bars","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Cocktail Bars","offsetgroup":"Cocktail Bars","orientation":"v","showlegend":true,"textposition":"auto","x":["Cocktail Bars"],"xaxis":"x","y":[411],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Style=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Breakfast & Brunch","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Breakfast & Brunch","offsetgroup":"Breakfast & Brunch","orientation":"v","showlegend":true,"textposition":"auto","x":["Breakfast & Brunch"],"xaxis":"x","y":[359],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Style=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Italian","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Italian","offsetgroup":"Italian","orientation":"v","showlegend":true,"textposition":"auto","x":["Italian"],"xaxis":"x","y":[266],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Style=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bars","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Bars","offsetgroup":"Bars","orientation":"v","showlegend":true,"textposition":"auto","x":["Bars"],"xaxis":"x","y":[157],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Style=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Seafood","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Seafood","offsetgroup":"Seafood","orientation":"v","showlegend":true,"textposition":"auto","x":["Seafood"],"xaxis":"x","y":[146],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Style=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Asian Fusion","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Asian Fusion","offsetgroup":"Asian Fusion","orientation":"v","showlegend":true,"textposition":"auto","x":["Asian Fusion"],"xaxis":"x","y":[142],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Style=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tapas\u002fSmall Plates","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Tapas\u002fSmall Plates","offsetgroup":"Tapas\u002fSmall Plates","orientation":"v","showlegend":true,"textposition":"auto","x":["Tapas\u002fSmall Plates"],"xaxis":"x","y":[131],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Style=%{x}\u003cb ...

# %%
mean_StarRating = df_exploded.copy()

mean_StarRating.Style = mean_StarRating.Style.str.strip()
mean_StarRating.head()
# Out:
#    Rank CommentDate       Date RestaurantName  \
# 0     1  2023-09-16 2023-09-17      GRANVILLE
# 1     1  2023-09-16 2023-09-17      GRANVILLE
# 2     1  2023-09-15 2023-09-17      GRANVILLE
# 3     1  2023-09-15 2023-09-17      GRANVILLE
# 4     1  2023-09-07 2023-09-17      GRANVILLE
#
#                                              Comment  \
# 0  Great ambiance indoors and attentive staff. Re...
# 1  Great ambiance indoors and attentive staff. Re...
# 2  Wrong wrong wrong.   AIf you don't fit the Ty ...
# 3  Wrong wrong wrong.   AIf you don't fit the Ty ...
# 4  Bad service!! The worst servers. Marcos the ma...
#
#                                       Address  StarRating  NumberOfReviews  \
# 0  8701 Beverly Blvd West Hollywood, CA 90048         4.4             2672
# 1  8701 Beverly Blvd West Hollywood, CA 90048         4.4             2672
# 2  8701 Beverly Blvd West Hollywood, CA 90048         4.4             2672
# 3  8701 Beverly Blvd West Hollywood, CA 90048         4.4             2672
# 4  8701 Beverly Blvd West Hollywood, CA 90048         4.4             2672
#
#             Style Price
# 0  American (New)    $$
# 1   Cocktail Bars    $$
# 2  American (New)    $$
# 3   Cocktail Bars    $$
# 4  American (New)    $$

# %%
mean_StarRating = mean_StarRating.groupby('Style')['StarRating'].mean().reset_index().sort_values(by="StarRating", ascending=False)
mean_StarRatingPlot = mean_StarRating.head(20)
mean_StarRatingPlot
# Out:
#              Style  StarRating
# 49         Laotian    4.900000
# 32     Food Stands    4.800000
# 73  Specialty Food    4.800000
# 85       Ukrainian    4.800000
# 86           Vegan    4.736667
# 38        Hawaiian    4.703226
# 56        Moroccan    4.700000
# 37           Halal    4.700000
# 1          African    4.700000
# 36     Gluten-Free    4.700000
# 63            Pubs    4.600000
# 87      Vegetarian    4.600000
# 65           Salad    4.600000
# 71        Southern    4.584314
# 31        Filipino    4.580488
# 19    Chicken Shop    4.557143
# 8         Barbeque    4.556944
# 26           Delis    4.521212
# 30       Fast Food    4.500000
# 50  Latin American    4.500000

# %%
fig = px.bar(mean_StarRatingPlot, x='Style', y='StarRating',
             title='Relationship between StarRating and Style',
             labels={'Style': 'Elements in StarRating', 'Count': 'Mean of StarRating'},
             color='Style')

# Limit the y-axis values
fig.update_yaxes(range=[4.4, 5])

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d8060ee6-3c10-4001-8a61-58f7dd445495" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8060ee6-3c10-4001-8a61-58f7dd445495")) {                    Plotly.newPlot(                        "d8060ee6-3c10-4001-8a61-58f7dd445495",                        [{"alignmentgroup":"True","hovertemplate":"Elements in StarRating=%{x}\u003cbr\u003eStarRating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Laotian","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Laotian","offsetgroup":"Laotian","orientation":"v","showlegend":true,"textposition":"auto","x":["Laotian"],"xaxis":"x","y":[4.9],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Elements in StarRating=%{x}\u003cbr\u003eStarRating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Food Stands","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Food Stands","offsetgroup":"Food Stands","orientation":"v","showlegend":true,"textposition":"auto","x":["Food Stands"],"xaxis":"x","y":[4.8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Elements in StarRating=%{x}\u003cbr\u003eStarRating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Specialty Food","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Specialty Food","offsetgroup":"Specialty Food","orientation":"v","showlegend":true,"textposition":"auto","x":["Specialty Food"],"xaxis":"x","y":[4.8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Elements in StarRating=%{x}\u003cbr\u003eStarRating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ukrainian","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Ukrainian","offsetgroup":"Ukrainian","orientation":"v","showlegend":true,"textposition":"auto","x":["Ukrainian"],"xaxis":"x","y":[4.8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Elements in StarRating=%{x}\u003cbr\u003eStarRating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Vegan","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Vegan","offsetgroup":"Vegan","orientation":"v","showlegend":true,"textposition":"auto","x":["Vegan"],"xaxis":"x","y":[4.736666666666666],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Elements in StarRating=%{x}\u003cbr\u003eStarRating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hawaiian","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Hawaiian","offsetgroup":"Hawaiian","orientation":"v","showlegend":true,"textposition":"auto","x":["Hawaiian"],"xaxis":"x","y":[4.703225806451612],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Elements in StarRating=%{x}\u003cbr\u003eStarRating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Moroccan","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Moroccan","offsetgroup":"Moroccan","orientation":"v","showlegend":true,"textposition":"auto","x":["Moroccan"],"xaxis":"x","y":[4.7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Elements in StarRating=%{x}\u003cbr\u003eStarRating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Halal","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Halal","offsetgroup":"Halal","orientation":"v","showlegend":true,"textposition":"auto","x":["Halal"],"xaxis":"x","y":[4.7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Elements in StarRating=%{x}\u003cbr\u003eStarRating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"African","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"African","offsetgroup":"African","orientation":"v","showlegend":true,"textposition":"auto","x":["African"]," ...

# %%
mean_RestaurantRating = df_exploded.copy()

mean_RestaurantRating.Style = mean_RestaurantRating.Style.str.strip()
mean_RestaurantRating.head()
# Out:
#    Rank CommentDate       Date RestaurantName  \
# 0     1  2023-09-16 2023-09-17      GRANVILLE
# 1     1  2023-09-16 2023-09-17      GRANVILLE
# 2     1  2023-09-15 2023-09-17      GRANVILLE
# 3     1  2023-09-15 2023-09-17      GRANVILLE
# 4     1  2023-09-07 2023-09-17      GRANVILLE
#
#                                              Comment  \
# 0  Great ambiance indoors and attentive staff. Re...
# 1  Great ambiance indoors and attentive staff. Re...
# 2  Wrong wrong wrong.   AIf you don't fit the Ty ...
# 3  Wrong wrong wrong.   AIf you don't fit the Ty ...
# 4  Bad service!! The worst servers. Marcos the ma...
#
#                                       Address  StarRating  NumberOfReviews  \
# 0  8701 Beverly Blvd West Hollywood, CA 90048         4.4             2672
# 1  8701 Beverly Blvd West Hollywood, CA 90048         4.4             2672
# 2  8701 Beverly Blvd West Hollywood, CA 90048         4.4             2672
# 3  8701 Beverly Blvd West Hollywood, CA 90048         4.4             2672
# 4  8701 Beverly Blvd West Hollywood, CA 90048         4.4             2672
#
#             Style Price
# 0  American (New)    $$
# 1   Cocktail Bars    $$
# 2  American (New)    $$
# 3   Cocktail Bars    $$
# 4  American (New)    $$

# %%
mean_RestaurantRating = mean_RestaurantRating.groupby('RestaurantName')['StarRating'].mean().reset_index().sort_values(by="StarRating", ascending=False)
mean_RestaurantRatingPlot = mean_RestaurantRating.head(20)
mean_RestaurantRatingPlot
# Out:
#                             RestaurantName  StarRating
# 170                      Reunion Hollywood         5.0
# 130                    Manse Korean Buffet         5.0
# 119                             Liu's Cafe         5.0
# 215                            Tita Lina’s         4.9
# 113                             Lan Noodle         4.9
# 233                                  hibi.         4.9
# 230                              Yum Sະlut         4.9
# 152                                 Olivia         4.9
# 41                             Cooking Mom         4.9
# 95                                   Joyce         4.8
# 139             Mom, Please Ukrainian Food         4.8
# 64                         Good Goose Cafe         4.8
# 117               Little Pan - Los Angeles         4.8
# 62                        Ghost Sando Shop         4.8
# 190  Spaccio Salumeria by Truffle Brothers         4.8
# 214           Three Borders Brunch & Grill         4.8
# 54                         Float Hollywood         4.8
# 40                Colibri - West Hollywood         4.8
# 171                           Rice Chicken         4.8
# 144                              Mun Patio         4.8

# %%
fig = px.bar(mean_RestaurantRatingPlot, x='RestaurantName', y='StarRating',
             title='Relationship between Restaurant and Average Rating',
             labels={'Style': 'Elements in StarRating', 'Count': 'Mean of StarRating'},
             color='RestaurantName')

# Limit the y-axis values
fig.update_yaxes(range=[4.4, 5])

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="28622d5d-1efe-4d76-aa02-0a9acfebba29" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28622d5d-1efe-4d76-aa02-0a9acfebba29")) {                    Plotly.newPlot(                        "28622d5d-1efe-4d76-aa02-0a9acfebba29",                        [{"alignmentgroup":"True","hovertemplate":"RestaurantName=%{x}\u003cbr\u003eStarRating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Reunion Hollywood","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Reunion Hollywood","offsetgroup":"Reunion Hollywood","orientation":"v","showlegend":true,"textposition":"auto","x":["Reunion Hollywood"],"xaxis":"x","y":[5.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"RestaurantName=%{x}\u003cbr\u003eStarRating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Manse Korean Buffet","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Manse Korean Buffet","offsetgroup":"Manse Korean Buffet","orientation":"v","showlegend":true,"textposition":"auto","x":["Manse Korean Buffet"],"xaxis":"x","y":[5.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"RestaurantName=%{x}\u003cbr\u003eStarRating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Liu's Cafe","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Liu's Cafe","offsetgroup":"Liu's Cafe","orientation":"v","showlegend":true,"textposition":"auto","x":["Liu's Cafe"],"xaxis":"x","y":[5.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"RestaurantName=%{x}\u003cbr\u003eStarRating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tita Lina\u2019s","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Tita Lina\u2019s","offsetgroup":"Tita Lina\u2019s","orientation":"v","showlegend":true,"textposition":"auto","x":["Tita Lina\u2019s"],"xaxis":"x","y":[4.9],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"RestaurantName=%{x}\u003cbr\u003eStarRating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Lan Noodle","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Lan Noodle","offsetgroup":"Lan Noodle","orientation":"v","showlegend":true,"textposition":"auto","x":["Lan Noodle"],"xaxis":"x","y":[4.9],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"RestaurantName=%{x}\u003cbr\u003eStarRating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"hibi.","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"hibi.","offsetgroup":"hibi.","orientation":"v","showlegend":true,"textposition":"auto","x":["hibi."],"xaxis":"x","y":[4.9],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"RestaurantName=%{x}\u003cbr\u003eStarRating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yum S\u0eb0lut","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Yum S\u0eb0lut","offsetgroup":"Yum S\u0eb0lut","orientation":"v","showlegend":true,"textposition":"auto","x":["Yum S\u0eb0lut"],"xaxis":"x","y":[4.9],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"RestaurantName=%{x}\u003cbr\u003eStarRating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Olivia","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Olivia","offsetgroup":"Olivia","orientation":"v","showlegend":true,"textposition":"auto","x":["Olivia"],"xaxis":"x","y":[4.9],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"RestaurantName=%{x}\u003cbr\u003eStarRating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cooking Mom","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Cooking Mom","offsetgroup":"Cooking Mom","orientation":"v","showlegend":true,"textpo ...

# %%
#Vader

nltk.download("vader_lexicon")
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.metrics import accuracy_score
import numpy as np
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
#source:  https://hex.tech/use-cases/sentiment-analysis/vader-sentiment-analysis/#:~:text=In%20identifying%20the%20sentiment%20of,sentiment%20score%20of%20the%20text.

VaderModel = SentimentIntensityAnalyzer()
def extract_score(text):
    score = VaderModel.polarity_scores(text)
    compound = score['compound']

    sentiment = 'neutral'
    if(compound >= 0.05):
        sentiment = "positive" #Fixed indentation

    elif(compound <= -0.05):
        sentiment = "negative" #Fixed indentation

    return sentiment

# %%
df.dropna(inplace = True)
df.isnull().sum()
# Out:
# Rank               0
# CommentDate        0
# Date               0
# RestaurantName     0
# Comment            0
# Address            0
# StarRating         0
# NumberOfReviews    0
# Style              0
# Price              0
# dtype: int64
