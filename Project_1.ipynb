# %% [markdown]
# <a href="https://colab.research.google.com/github/ToriStoner/Assignment-2-Data-/blob/main/Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
import json

# %%
df = pd.read_csv("Crime_Data.csv")
df.head()
# Out:
#    RecordID                          Offense    IncidentID  BlockNumber  \
# 0         1  Assist Citizen - Mental/TDO/ECO  202400034093        900.0
# 1         2    Larceny - Of Veh Parts/Access  202400034075       1600.0
# 2         3                      Hit and Run  202400034071        900.0
# 3         4               Disorderly Conduct  202400034068        900.0
# 4         5               Lost/FoundProperty  202400034047        700.0
#
#         StreetName Agency            DateReported  HourReported  \
# 0   ELLIOTT AVE, A    CPD  2024/10/02 00:24:02+00          2024
# 1    6TH ST SE, 28    CPD  2024/10/01 21:38:47+00          1738
# 2       EMMET ST N    CPD  2024/10/01 21:11:45+00          1711
# 3  ST CLAIR AVE, A    CPD  2024/10/01 20:59:17+00          1659
# 4         RUGBY RD    CPD  2024/10/01 18:23:15+00          1423
#
#   ReportingOfficer
# 0  Venereo, Arturo
# 1     Kirby, Tyree
# 2    Bland, Johnnà
# 3  Prevost, Payten
# 4   Brannon, Devin

# %%
#json_df = pd.read_json("covid.json")

file_path = "Drug Event.json"

# Try to read the JSON file, handling potential errors
try:
    json_df = pd.read_json(file_path)
except ValueError as e:
    # If ValueError occurs, try reading with 'lines=True'
    try:
        json_df = pd.read_json(file_path, lines=True)
    except ValueError as e:
        # If still an error, print the error and a portion of the file content
        print(f"Error reading JSON: {e}")
        with open(file_path, "r") as f:
            print("First 100 characters of the file:")
            print(f.read(100))
# Out:
# Error reading JSON: Unexpected character found when decoding 'null'
# First 100 characters of the file:
# numb": "20",
#             "drugstructuredosageunit": "003",
#             "drugintervaldosageunitnumb":
